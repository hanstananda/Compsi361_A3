# %%
import time
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
with open("supermarket.csv") as f:
    content = f.readlines()

transaction_list = []

for line in content: 
    # print(line)
    items_purchased = [i.strip() for i in line.split(',')]
    # print(items_purchased)
    transaction_list.append(items_purchased)

# print(transaction_list[:5])  # Sanity check of the result

# %%
te = TransactionEncoder()
te_transactions = te.fit(transaction_list).transform(transaction_list)
df = pd.DataFrame(te_transactions, columns=te.columns_)
print(len(te.columns_))
# print(df)
# Out:
# 124

# %%
def timer(fun):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        res = fun(*args, **kwargs)
        print("--- %s seconds ---" % (round(time.time() - start_time, 3)))
        return res
    return wrapper

@timer
def search_fp_growth(data_frame, itemsets_needed, treshold=0.01):
    hi = 1
    lo = 0
    itemsets = []
    while((hi-lo)>treshold):
        mid = (lo+hi)/2
        itemsets = fpgrowth(df=data_frame, min_support=mid, use_colnames=True)
        if len(itemsets)<itemsets_needed:
            hi=mid
        else:
            lo=mid
    print("Final min support=",mid)
    return itemsets

# %%
wanted_itemset_length = 50
print(wanted_itemset_length)
final_itemsets = search_fp_growth(df, itemsets_needed=wanted_itemset_length)
final_itemsets
# Out:
# 50
# Final min support= 0.3671875
# --- 1.576 seconds ---
#      support                             itemsets
# 0   0.719689                     (bread and cake)
# 1   0.640156                              (fruit)
# 2   0.639939                         (vegetables)
# 3   0.635185                         (milk-cream)
# 4   0.604063                       (baking needs)
# 5   0.587206                       (frozen foods)
# 6   0.563000                           (biscuits)
# 7   0.532310                  (juice-sat-cord-ms)
# 8   0.503566                  (party snack foods)
# 9   0.494489                          (margarine)
# 10  0.485628                  (tissues-paper prd)
# 11  0.475686                  (sauces-gravy-pkle)
# 12  0.406095                             (cheese)
# 13  0.637130                        (total = low)
# 14  0.403501                          (pet foods)
# 15  0.400692                      (department137)
# 16  0.375837                               (beef)
# 17  0.402421                     (breakfast food)
# 18  0.408040                        (soft drinks)
# 19  0.502485              (fruit, bread and cake)
# 20  0.496650         (vegetables, bread and cake)
# 21  0.476983                  (vegetables, fruit)
# 22  0.387076  (vegetables, fruit, bread and cake)
# 23  0.505079         (milk-cream, bread and cake)
# 24  0.440458                  (milk-cream, fruit)
# 25  0.437649             (vegetables, milk-cream)
# 26  0.372163            (total = low, milk-cream)
# 27  0.473525       (baking needs, bread and cake)
# 28  0.421223           (vegetables, baking needs)
# 29  0.412146           (baking needs, milk-cream)
# 30  0.410633                (baking needs, fruit)
# 31  0.460125       (frozen foods, bread and cake)
# 32  0.406743           (vegetables, frozen foods)
# 33  0.402204                (fruit, frozen foods)
# 34  0.396585         (baking needs, frozen foods)
# 35  0.394640           (milk-cream, frozen foods)
# 36  0.450184           (biscuits, bread and cake)
# 37  0.397018                    (fruit, biscuits)
# 38  0.391182             (frozen foods, biscuits)
# 39  0.381889               (milk-cream, biscuits)
# 40  0.381241             (baking needs, biscuits)
# 41  0.381241               (vegetables, biscuits)
# 42  0.403933  (juice-sat-cord-ms, bread and cake)
# 43  0.390750  (party snack foods, bread and cake)
# 44  0.395721          (margarine, bread and cake)
# 45  0.383834  (tissues-paper prd, bread and cake)
# 46  0.369570  (sauces-gravy-pkle, bread and cake)
# 47  0.371515                 (total = low, fruit)
# 48  0.414307        (total = low, bread and cake)

# %%
@timer
def search_association_rules(frequent_itemsets, rules_needed, arguments, treshold=0.01):
    hi = 100
    lo = arguments['min_threshold']
    rules = []
    final_min_tresh = hi
    while((hi-lo)>treshold):
        mid = (lo+hi)/2
        arguments['min_threshold'] = mid
        rules = association_rules(frequent_itemsets, **arguments)
        if len(rules)<rules_needed:
            hi=mid
        else:
            print(final_min_tresh)
            final_min_tresh=min(final_min_tresh, mid)
            lo=mid
    print("Final min ",arguments['metric'],"=",final_min_tresh)
    print(len(rules))
    arguments['min_threshold'] =final_min_tresh
    rules = association_rules(frequent_itemsets, **arguments)
    return rules

# %%
association_rules_arguments = dict(
    metric="lift", 
    min_threshold=1
)
final_rules = search_association_rules(final_itemsets, 40, association_rules_arguments)
print(final_rules.sort_values('lift', ascending=False)[['antecedents', 'consequents', 'lift', 'confidence' ]])
# Out:
# 100
# 1.04833984375
# Final min  lift = 1.04833984375
# 38
# --- 0.052 seconds ---
#                      antecedents                   consequents      lift  \
# 7   (vegetables, bread and cake)                       (fruit)  1.217475
# 10                       (fruit)  (vegetables, bread and cake)  1.217475
# 8        (fruit, bread and cake)                  (vegetables)  1.203743
# 9                   (vegetables)       (fruit, bread and cake)  1.203743
# 40                (frozen foods)                    (biscuits)  1.183261
# 41                    (biscuits)                (frozen foods)  1.183261
# 4                   (vegetables)                       (fruit)  1.164336
# 5                        (fruit)                  (vegetables)  1.164336
# 6            (vegetables, fruit)              (bread and cake)  1.127583
# 11              (bread and cake)           (vegetables, fruit)  1.127583
# 45                    (biscuits)                (baking needs)  1.121008
# 44                (baking needs)                    (biscuits)  1.121008
# 33                (frozen foods)                (baking needs)  1.118057
# 32                (baking needs)                (frozen foods)  1.118057
# 53              (bread and cake)                   (margarine)  1.111956
# 52                   (margarine)              (bread and cake)  1.111956
# 36                    (biscuits)              (bread and cake)  1.111058
# 37              (bread and cake)                    (biscuits)  1.111058
# 13              (bread and cake)                  (milk-cream)  1.104878
# 12                  (milk-cream)              (bread and cake)  1.104878
# 38                       (fruit)                    (biscuits)  1.101580
# 39                    (biscuits)                       (fruit)  1.101580
# 55              (bread and cake)           (tissues-paper prd)  1.098235
# 54           (tissues-paper prd)              (bread and cake)  1.098235
# 1               (bread and cake)                       (fruit)  1.090670
# 0                        (fruit)              (bread and cake)  1.090670
# 21                (baking needs)                  (vegetables)  1.089660
# 20                  (vegetables)                (baking needs)  1.089660
# 19              (bread and cake)                (baking needs)  1.089221
# 18                (baking needs)              (bread and cake)  1.089221
# 26                (frozen foods)              (bread and cake)  1.088783
# 27              (bread and cake)                (frozen foods)  1.088783
# 14                  (milk-cream)                       (fruit)  1.083226
# 15                       (fruit)                  (milk-cream)  1.083226
# 29                (frozen foods)                  (vegetables)  1.082408
# 28                  (vegetables)                (frozen foods)  1.082408
# 57              (bread and cake)           (sauces-gravy-pkle)  1.079522
# 56           (sauces-gravy-pkle)              (bread and cake)  1.079522
# 3               (bread and cake)                  (vegetables)  1.078368
# 2                   (vegetables)              (bread and cake)  1.078368
# 51              (bread and cake)           (party snack foods)  1.078196
# 50           (party snack foods)              (bread and cake)  1.078196
# 16                  (vegetables)                  (milk-cream)  1.076680
# 17                  (milk-cream)                  (vegetables)  1.076680
# 23                  (milk-cream)                (baking needs)  1.074160
# 22                (baking needs)                  (milk-cream)  1.074160
# 30                       (fruit)                (frozen foods)  1.069969
# 31                (frozen foods)                       (fruit)  1.069969
# 42                  (milk-cream)                    (biscuits)  1.067895
# 43                    (biscuits)                  (milk-cream)  1.067895
# 24                (baking needs)                       (fruit)  1.061906
# 25                       (fruit)                (baking needs)  1.061906
# 46                  (vegetables)                    (biscuits)  1.058161
# 47                    (biscuits)                  (vegetables)  1.058161
# 34                  (milk-cream)                (frozen foods)  1.058062
# 35                (frozen foods)                  (milk-cream)  1.058062
# 49              (bread and cake)           (juice-sat-cord-ms)  1.054387
# 48           (juice-sat-cord-ms)              (bread and cake)  1.054387
#
#     confidence
# 7     0.779373
# 10    0.604659
# 8     0.770323
# 9     0.604863
# 40    0.666176
# 41    0.694818
# 4     0.745356
# 5     0.745105
# 6     0.811509
# 11    0.537838
# 45    0.677159
# 44    0.631127
# 33    0.675377
# 32    0.656530
# 53    0.549850
# 52    0.800262
# 36    0.799616
# 37    0.625526
# 13    0.701802
# 12    0.795168
# 38    0.620189
# 39    0.705182
# 55    0.533333
# 54    0.790387
# 1     0.698198
# 0     0.784943
# 21    0.697317
# 20    0.658224
# 19    0.657958
# 18    0.783900
# 26    0.783585
# 27    0.639339
# 14    0.693433
# 15    0.688049
# 29    0.692676
# 28    0.635596
# 57    0.513514
# 56    0.776920
# 3     0.690090
# 2     0.776089
# 51    0.542943
# 50    0.775966
# 16    0.683891
# 17    0.689010
# 23    0.648860
# 22    0.682290
# 30    0.628292
# 31    0.684947
# 42    0.601225
# 43    0.678311
# 24    0.679785
# 25    0.641458
# 46    0.595745
# 47    0.677159
# 34    0.621300
# 35    0.672065
# 49    0.561261
# 48    0.758831

# %%
@timer
def start_association_rules(frequent_itemsets, arguments):
    rules = association_rules(frequent_itemsets, **arguments)
    return rules

# %%
association_rules_arguments = dict(
    metric="lift", 
    min_threshold=1
)
rules = start_association_rules(final_itemsets, association_rules_arguments)
print(rules.sort_values('lift', ascending=False)[:20][['antecedents', 'consequents', 'lift', 'confidence' ]])
# Out:
# --- 0.52 seconds ---
#                      antecedents                   consequents      lift  \
# 3   (vegetables, bread and cake)                       (fruit)  1.217475
# 6                        (fruit)  (vegetables, bread and cake)  1.217475
# 4        (fruit, bread and cake)                  (vegetables)  1.203743
# 5                   (vegetables)       (fruit, bread and cake)  1.203743
# 35                (baking needs)                   (margarine)  1.190221
# 34                   (margarine)                (baking needs)  1.190221
# 29                    (biscuits)                (frozen foods)  1.183261
# 28                (frozen foods)                    (biscuits)  1.183261
# 1                        (fruit)                  (vegetables)  1.164336
# 0                   (vegetables)                       (fruit)  1.164336
# 10           (milk-cream, fruit)              (bread and cake)  1.148136
# 15              (bread and cake)           (milk-cream, fruit)  1.148136
# 12       (fruit, bread and cake)                  (milk-cream)  1.140300
# 13                  (milk-cream)       (fruit, bread and cake)  1.140300
# 16      (vegetables, milk-cream)              (bread and cake)  1.137666
# 21              (bread and cake)      (vegetables, milk-cream)  1.137666
# 17  (vegetables, bread and cake)                  (milk-cream)  1.135885
# 20                  (milk-cream)  (vegetables, bread and cake)  1.135885
# 7               (bread and cake)           (vegetables, fruit)  1.127583
# 2            (vegetables, fruit)              (bread and cake)  1.127583
#
#     confidence
# 3     0.779373
# 6     0.604659
# 4     0.770323
# 5     0.604863
# 35    0.588551
# 34    0.718969
# 29    0.694818
# 28    0.666176
# 1     0.745105
# 0     0.745356
# 10    0.826300
# 15    0.505706
# 12    0.724301
# 13    0.572984
# 16    0.818765
# 21    0.497898
# 17    0.721497
# 20    0.564137
# 7     0.537838
# 2     0.811509
